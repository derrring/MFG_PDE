# %% [markdown]
# # Tutorial 03: 2D Geometry
#
# This tutorial demonstrates how to work with **two-dimensional** spatial domains in MFGArchon. We model **crowd navigation with target attraction** -- agents start at the corners of a room and move toward a central target.
#
# ## Mathematical Problem
#
# We solve the HJB-FP system on $\Omega = [0, 10] \times [0, 10]$, $t \in [0, T]$:
#
# **HJB (backward):**
# $$-\partial_t u - \frac{\sigma^2}{2} \Delta u + \frac{1}{2}|\nabla u|^2 = \lambda \, m$$
#
# **FP (forward):**
# $$\partial_t m - \frac{\sigma^2}{2} \Delta m + \nabla \cdot (m \, \nabla u) = 0$$
#
# where $\nabla = (\partial_x, \partial_y)$ and $\Delta = \partial_{xx} + \partial_{yy}$ are now **2D operators**.
#
# ### Problem Setup
#
# - **Domain:** Square room $[0, 10]^2$
# - **Target:** Center of the room $(5, 5)$
# - **Terminal cost:** $u_T(x, y) = (x - 5)^2 + (y - 5)^2$ -- agents want to reach the center
# - **Initial density:** Four Gaussian blobs at corners $(2,2)$, $(8,2)$, $(2,8)$, $(8,8)$
# - **Hamiltonian:** Standard LQ with congestion: $H = \frac{1}{2}|p|^2 + \lambda m$
# - **Boundary:** No-flux (reflecting walls) on all four sides
#
# ### What changes in 2D
#
# - The grid is now a **tensor product** $N_x \times N_y$
# - Initial density and terminal cost are 2D arrays
# - The Laplacian uses a **5-point stencil** (2D finite differences)
# - Computation is more expensive: $O(N_x \cdot N_y \cdot N_t)$ per Picard iteration

# %% [markdown]
# ## Step 1: Create the 2D Grid
#
# The `TensorProductGrid` accepts a list of bounds and resolutions for each dimension. For 2D, we pass two bounds and two point counts.

# %%
import numpy as np

from mfgarchon import Conditions, MFGProblem, Model
from mfgarchon.core.hamiltonian import QuadraticControlCost, SeparableHamiltonian
from mfgarchon.geometry import TensorProductGrid
from mfgarchon.geometry.boundary import no_flux_bc

# Problem parameters
TARGET = np.array([5.0, 5.0])  # Target location (center of room)
CONGESTION_WEIGHT = 1.0
GRID_RESOLUTION = 15  # Reduced from 30 for faster execution
SIGMA = 0.3

# Create 2D geometry
geometry = TensorProductGrid(
    bounds=[(0.0, 10.0), (0.0, 10.0)],  # [(xmin, xmax), (ymin, ymax)]
    Nx_points=[GRID_RESOLUTION, GRID_RESOLUTION],
    boundary_conditions=no_flux_bc(dimension=2),
)

print(f"Domain: {geometry.get_bounds()}")
print(f"Grid: {GRID_RESOLUTION} x {GRID_RESOLUTION} = {GRID_RESOLUTION**2} spatial points")

# %% [markdown]
# ## Step 2: Define Model and Conditions
#
# The **Model** captures game rules (Hamiltonian + diffusion). The **Conditions** capture problem data (terminal cost, initial density, time horizon) as **callables** -- resolution-independent functions that work on any grid.
#
# The initial density places four Gaussian blobs at the corners of the room:
#
# $$m_0(x, y) \propto \sum_{(c_x, c_y) \in \text{corners}} \exp\left(-5\left[(x - c_x)^2 + (y - c_y)^2\right]\right)$$
#
# The terminal cost is the squared distance to the target:
#
# $$u_T(x, y) = (x - 5)^2 + (y - 5)^2$$

# %%
# Corner locations for initial density
corners = [
    (2.0, 2.0),  # Bottom-left
    (8.0, 2.0),  # Bottom-right
    (2.0, 8.0),  # Top-left
    (8.0, 8.0),  # Top-right
]

# Hamiltonian: H = (1/2)|p|^2 + lambda*m
hamiltonian = SeparableHamiltonian(
    control_cost=QuadraticControlCost(control_cost=1.0),
    coupling=lambda m: CONGESTION_WEIGHT * m,
    coupling_dm=lambda m: CONGESTION_WEIGHT,
)

model = Model(hamiltonian=hamiltonian, sigma=SIGMA)


# Terminal cost: distance to target (callable, resolution-independent)
def terminal_cost(x):
    """Distance to target. x shape: (2,) for a single 2D point."""
    return (x[0] - TARGET[0]) ** 2 + (x[1] - TARGET[1]) ** 2


# Initial density: 4 Gaussian blobs at corners (callable, resolution-independent)
def initial_density(x):
    """4 Gaussian blobs at corners. x shape: (2,) for a single 2D point."""
    m = 0.0
    for cx, cy in corners:
        m += np.exp(-5 * ((x[0] - cx) ** 2 + (x[1] - cy) ** 2))
    return m


conditions = Conditions(
    u_terminal=terminal_cost,
    m_initial=initial_density,
    T=2.0,
)

print("Model: H = (1/2)|p|^2 + lambda*m")
print(f"Diffusion: sigma = {SIGMA}")
print(f"Time horizon: T = {conditions.T}")
print(f"Initial density: 4 Gaussian blobs at corners {corners}")

# %% [markdown]
# ## Step 3: Create and Solve
#
# The v1.0 API separates concerns: `Model` (game rules), `Conditions` (problem data), and `domain` (spatial grid). The solver API is identical to 1D -- the grid dimensionality is handled internally. Note that 2D problems are more computationally intensive.

# %%
# Create problem (v1.0 API: model + domain + conditions)
problem = MFGProblem(model=model, domain=geometry, conditions=conditions, Nt=20)

print(f"Target: {TARGET}")
print(f"Time horizon: T = {problem.T}")
print(f"Diffusion: sigma = {problem.sigma}")
print()
print("Solving 2D MFG system...")
print("(This may take a moment -- 2D problems are more computationally intensive)")

result = problem.solve(verbose=True)

print(f"\nConverged: {result.converged} (iterations: {result.iterations})")

# %% [markdown]
# ## Step 4: Mass Conservation Check
#
# A critical validation in 2D: total mass $\int_\Omega m(t, x, y) \, dx \, dy$ should remain constant across time steps. We use the trapezoidal rule for numerical integration.

# %%
grid_shape = geometry.get_grid_shape()
dx, dy = geometry.get_grid_spacing()

# Check mass at each timestep
masses = []
for t_idx in range(result.M.shape[0]):
    m_2d = result.M[t_idx].reshape(grid_shape)
    mass = np.trapezoid(np.trapezoid(m_2d, dx=dy, axis=1), dx=dx)
    masses.append(mass)

print(f"Initial mass: {masses[0]:.6f}")
print(f"Final mass:   {masses[-1]:.6f}")
print(f"Mass drift:   {abs(masses[-1] - masses[0]):.6e}")

# %% [markdown]
# ## Step 5: Visualize 2D Density Evolution
#
# We plot the density $m(t, x, y)$ at four time snapshots. The red star marks the target at $(5, 5)$.
#
# **What to observe:**
# - At $t=0$: Four distinct blobs at the corners
# - As time progresses: Blobs migrate toward the center target
# - Congestion coupling causes agents to spread rather than all converging to a single point
# - Diffusion smooths the density profile over time

# %%
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(15, 10))

# Spatial grids for plotting
x_1d = np.linspace(0, 10, GRID_RESOLUTION)
y_1d = np.linspace(0, 10, GRID_RESOLUTION)
X, Y = np.meshgrid(x_1d, y_1d, indexing="ij")

# Time points to plot
t_space = np.linspace(0, problem.T, problem.Nt + 1)
times_to_plot = [0, len(t_space) // 3, 2 * len(t_space) // 3, -1]

for idx, t_idx in enumerate(times_to_plot, 1):
    ax = fig.add_subplot(2, 2, idx)

    m_2d = result.M[t_idx].reshape(grid_shape)

    contour = ax.contourf(X, Y, m_2d, levels=20, cmap="viridis")
    ax.plot(*TARGET, "r*", markersize=20, label="Target")
    ax.set_xlabel("x")
    ax.set_ylabel("y")
    ax.set_title(f"Density at t={t_space[t_idx]:.2f}s")
    ax.set_aspect("equal")
    plt.colorbar(contour, ax=ax)
    ax.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Summary
#
# | Concept | 1D | 2D |
# |:--------|:---|:---|
# | Grid | `bounds=[(0,1)], Nx_points=[51]` | `bounds=[(0,10),(0,10)], Nx_points=[15,15]` |
# | Boundary | `no_flux_bc(dimension=1)` | `no_flux_bc(dimension=2)` |
# | Density shape | `(Nt+1, Nx)` | `(Nt+1, Nx*Ny)` -- reshape to `(Nx, Ny)` for plotting |
# | Computation | Fast | O(Nx * Ny) per time step -- reduce resolution for exploration |
#
# **Key API elements for 2D (v1.0):**
# - `TensorProductGrid(bounds=[(xmin,xmax), (ymin,ymax)], Nx_points=[Nx, Ny])` -- spatial domain
# - `no_flux_bc(dimension=2)` -- reflecting walls on all four sides
# - `Model(hamiltonian=..., sigma=...)` -- game rules (Hamiltonian + diffusion)
# - `Conditions(u_terminal=f, m_initial=g, T=...)` -- callables for resolution-independent conditions
# - `MFGProblem(model=..., domain=..., conditions=..., Nt=...)` -- unified problem constructor
# - Use `result.M[t_idx].reshape(grid_shape)` to recover the 2D spatial structure
#
# **Next:** [Tutorial 04 -- Advanced Solver Configuration](./04_particle_methods.ipynb)
