# %% [markdown]
# # Tutorial 05: Problem Variations and Parameter Studies
#
# This tutorial demonstrates how to **systematically vary problem parameters** and analyze their effects on MFG solutions.
#
# ## Mathematical Background
#
# We study the standard LQ-MFG system:
#
# $$-\partial_t u - \frac{\sigma^2}{2} \Delta u + \frac{1}{2}|\nabla u|^2 = \lambda \, m$$
# $$\partial_t m - \frac{\sigma^2}{2} \Delta m + \nabla \cdot (m \, \nabla u) = 0$$
#
# and explore how three key parameters affect the solution:
#
# 1. **Diffusion** $\sigma$: controls stochastic noise in agent dynamics $dX_t = \alpha_t \, dt + \sigma \, dW_t$
# 2. **Coupling strength** $\lambda$: controls congestion penalty in $F(m) = \lambda m$
# 3. **Grid resolution** $N_x$: controls spatial discretization accuracy
#
# ### Expected Effects
#
# | Parameter | Low Value | High Value |
# |:----------|:----------|:-----------|
# | $\sigma$ | Sharp density peaks, agents follow optimal paths closely | Smooth density, agents diffuse more |
# | $\lambda$ | Agents ignore crowding | Agents spread out to avoid congestion |
# | $N_x$ | Coarse approximation | High accuracy (but more computation) |

# %% [markdown]
# ## Setup: Helper Function
#
# We define a helper to create standard LQ components with variable coupling strength.

# %%
import numpy as np

from mfgarchon import Conditions, MFGProblem, Model
from mfgarchon.core.hamiltonian import QuadraticControlCost, SeparableHamiltonian
from mfgarchon.geometry import TensorProductGrid
from mfgarchon.geometry.boundary import no_flux_bc


def create_lq_model_and_conditions(coupling_strength: float = 0.5, sigma: float = 0.15, T: float = 1.0):
    """
    Create standard LQ-MFG model and conditions.

    H(p,m) = (1/2)|p|^2 + coupling * m
    Terminal cost: (x - 0.5)^2
    Initial density: Gaussian at center
    """
    hamiltonian = SeparableHamiltonian(
        control_cost=QuadraticControlCost(control_cost=1.0),
        coupling=lambda m: coupling_strength * m,
        coupling_dm=lambda m: coupling_strength,
    )

    model = Model(hamiltonian=hamiltonian, sigma=sigma)
    conditions = Conditions(
        u_terminal=lambda x: (x - 0.5) ** 2,
        m_initial=lambda x: np.exp(-50 * (x - 0.5) ** 2),
        T=T,
    )
    return model, conditions

# %% [markdown]
# ## Study 1: Diffusion Parameter $\sigma$
#
# The diffusion coefficient $\sigma$ appears in the SDE governing individual agent dynamics:
#
# $$dX_t = \alpha_t \, dt + \sigma \, dW_t$$
#
# Higher $\sigma$ means more randomness. In the PDE, it controls the viscosity $\frac{\sigma^2}{2} \Delta$. As $\sigma \to 0$, the MFG approaches a deterministic optimal control problem.

# %%
diffusion_values = [0.05, 0.15, 0.30]
results_diffusion = {}

for sigma in diffusion_values:
    print(f"Solving with sigma={sigma}...")
    geometry = TensorProductGrid(bounds=[(0.0, 1.0)], Nx_points=[51], boundary_conditions=no_flux_bc(dimension=1))
    model, conditions = create_lq_model_and_conditions(coupling_strength=0.5, sigma=sigma)
    problem = MFGProblem(
        model=model,
        domain=geometry,
        conditions=conditions,
        Nt=50,
    )
    results_diffusion[sigma] = problem.solve(verbose=False)
    print(f"  Converged in {results_diffusion[sigma].iterations} iterations")

print()

# %% [markdown]
# ## Study 2: Coupling Strength $\lambda$
#
# The coupling $F(m) = \lambda m$ determines the congestion cost. With $\lambda = 0$, agents ignore each other entirely. With large $\lambda$, avoiding crowded areas dominates the agents' decisions.

# %%
coupling_values = [0.0, 0.5, 2.0]
results_coupling = {}

for coupling in coupling_values:
    print(f"Solving with coupling={coupling}...")
    geometry = TensorProductGrid(bounds=[(0.0, 1.0)], Nx_points=[51], boundary_conditions=no_flux_bc(dimension=1))
    model, conditions = create_lq_model_and_conditions(coupling_strength=coupling)
    problem = MFGProblem(
        model=model,
        domain=geometry,
        conditions=conditions,
        Nt=50,
    )
    results_coupling[coupling] = problem.solve(verbose=False)
    print(f"  Converged in {results_coupling[coupling].iterations} iterations")

print()

# %% [markdown]
# ## Study 3: Grid Resolution $N_x$
#
# Spatial resolution affects the accuracy of the finite-difference approximation. The FDM discretization error is $O(\Delta x^2)$ for second-order schemes. We keep the CFL ratio $\Delta t / \Delta x$ approximately constant by setting $N_t = N_x$.

# %%
Nx_values = [26, 51, 101]
results_grid = {}

for Nx in Nx_values:
    print(f"Solving with Nx={Nx} grid points...")
    geometry = TensorProductGrid(bounds=[(0.0, 1.0)], Nx_points=[Nx], boundary_conditions=no_flux_bc(dimension=1))
    model, conditions = create_lq_model_and_conditions(coupling_strength=0.5)
    problem = MFGProblem(
        model=model,
        domain=geometry,
        conditions=conditions,
        Nt=Nx,  # Keep dt/dx ratio constant
    )
    results_grid[Nx] = problem.solve(verbose=False)
    print(f"  Converged in {results_grid[Nx].iterations} iterations")

print()

# %% [markdown]
# ## Analysis: Mass Conservation and Solution Quality
#
# For each parameter variation, we verify mass conservation $\int m(t,x)\,dx = \text{const}$.

# %%
print("Mass Conservation Check (diffusion variations):")
for sigma, result in results_diffusion.items():
    Nx = result.M.shape[1]
    dx = 1.0 / (Nx - 1)
    initial_mass = np.sum(result.M[0, :]) * dx
    final_mass = np.sum(result.M[-1, :]) * dx
    print(
        f"  sigma={sigma}: Initial={initial_mass:.4f}, "
        f"Final={final_mass:.4f}, Drift={abs(final_mass - initial_mass):.2e}"
    )

print()

# Key outputs summary
print("Key outputs from any MFG solution:")
print()
print(f"  {'Attribute':<20} {'Description'}")
print("  " + "-" * 50)
print(f"  {'result.U':<20} Value function u(t,x)")
print(f"  {'result.M':<20} Density m(t,x)")
print(f"  {'result.converged':<20} Convergence status")
print(f"  {'result.iterations':<20} Number of iterations")
print(f"  {'result.max_error':<20} Final convergence error")

# %% [markdown]
# ## Visualize Parameter Studies
#
# **What to observe:**
# - **Top row (density):** Higher $\sigma$ smooths the density; higher coupling flattens it; finer grids give sharper profiles
# - **Bottom row (value function):** The terminal cost shape is consistent across settings, but coupling and diffusion shift the value function level

# %%
import matplotlib.pyplot as plt

fig, axes = plt.subplots(2, 3, figsize=(15, 10))

# Row 1: Final densities
ax = axes[0, 0]
for sigma, result in results_diffusion.items():
    x_grid = np.linspace(0, 1, result.M.shape[1])
    ax.plot(x_grid, result.M[-1, :], label=f"sigma={sigma}")
ax.set_xlabel("x")
ax.set_ylabel("m(T, x)")
ax.set_title("Final Density: Diffusion Study")
ax.legend()
ax.grid(True, alpha=0.3)

ax = axes[0, 1]
for coupling, result in results_coupling.items():
    x_grid = np.linspace(0, 1, result.M.shape[1])
    ax.plot(x_grid, result.M[-1, :], label=f"coup={coupling}")
ax.set_xlabel("x")
ax.set_ylabel("m(T, x)")
ax.set_title("Final Density: Coupling Study")
ax.legend()
ax.grid(True, alpha=0.3)

ax = axes[0, 2]
for Nx, result in results_grid.items():
    x_grid = np.linspace(0, 1, result.M.shape[1])
    ax.plot(x_grid, result.M[-1, :], label=f"Nx={Nx}")
ax.set_xlabel("x")
ax.set_ylabel("m(T, x)")
ax.set_title("Final Density: Resolution Study")
ax.legend()
ax.grid(True, alpha=0.3)

# Row 2: Value functions
ax = axes[1, 0]
for sigma, result in results_diffusion.items():
    x_grid = np.linspace(0, 1, result.U.shape[1])
    ax.plot(x_grid, result.U[-1, :], label=f"sigma={sigma}")
ax.set_xlabel("x")
ax.set_ylabel("u(T, x)")
ax.set_title("Terminal Value: Diffusion Study")
ax.legend()
ax.grid(True, alpha=0.3)

ax = axes[1, 1]
for coupling, result in results_coupling.items():
    x_grid = np.linspace(0, 1, result.U.shape[1])
    ax.plot(x_grid, result.U[-1, :], label=f"coup={coupling}")
ax.set_xlabel("x")
ax.set_ylabel("u(T, x)")
ax.set_title("Terminal Value: Coupling Study")
ax.legend()
ax.grid(True, alpha=0.3)

ax = axes[1, 2]
for Nx, result in results_grid.items():
    x_grid = np.linspace(0, 1, result.U.shape[1])
    ax.plot(x_grid, result.U[-1, :], label=f"Nx={Nx}")
ax.set_xlabel("x")
ax.set_ylabel("u(T, x)")
ax.set_title("Terminal Value: Resolution Study")
ax.legend()
ax.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Summary
#
# ### Parameter Effects
#
# | Parameter | High Value Effect |
# |:----------|:------------------|
# | Diffusion $\sigma$ | More spreading, smoother density |
# | Coupling $\lambda$ | Stronger congestion avoidance |
# | Resolution $N_x$ | Higher accuracy, more computation |
# | Time horizon $T$ | More time for dynamics to evolve |
#
# ### Practical Guidance
#
# - **Prototyping:** Use coarse grids ($N_x \approx 25$) and loose tolerance ($10^{-3}$)
# - **Validation:** Run convergence studies by refining $N_x$ and checking solution stability
# - **Publication:** Use fine grids and tight tolerance, report grid convergence rates
#
# **Next steps:**
# - Explore `examples/advanced/` for complex geometries
# - See `examples/applications/` for real-world problems
# - [Tutorial 06 -- Boundary Condition Coupling](./06_boundary_condition_coupling.ipynb)
