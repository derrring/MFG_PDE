# %% [markdown]
# # Tutorial 01: Hello Mean Field Games
#
# This tutorial solves the simplest Mean Field Game — the **Linear-Quadratic (LQ) MFG** on a 1D domain.
#
# ## Mathematical Problem
#
# We solve the coupled HJB-FP system on $\Omega = [0, 1]$, $t \in [0, T]$:
#
# **Hamilton-Jacobi-Bellman (backward in time):**
# $$-\partial_t u - \frac{\sigma^2}{2} \Delta u + \frac{1}{2}|\nabla u|^2 = F(m)$$
#
# **Fokker-Planck (forward in time):**
# $$\partial_t m - \frac{\sigma^2}{2} \Delta m + \nabla \cdot (m \, \nabla u) = 0$$
#
# where:
# - $u(t,x)$ is the **value function** (cost-to-go for a representative agent)
# - $m(t,x)$ is the **population density** (distribution of agents)
# - $F(m) = \lambda \cdot m$ is a **linear congestion coupling** (crowded = costly)
# - $\sigma$ is the **noise intensity** (random perturbations in agent dynamics)
#
# **Boundary conditions:** No-flux (reflecting walls): $\nabla u \cdot n = 0$, $J \cdot n = 0$
#
# **Terminal/Initial conditions:**
# - $u(T, x) = (x - 0.5)^2$ — agents want to be at $x = 0.5$ at final time
# - $m(0, x) \propto \exp(-50(x-0.5)^2)$ — agents start concentrated near center

# %% [markdown]
# ## Step 1: Define the Domain
#
# We discretize $[0, 1]$ with 51 grid points (50 intervals, spacing $\Delta x = 0.02$).

# %%
import numpy as np

from mfgarchon import MFGProblem
from mfgarchon.core import MFGComponents
from mfgarchon.core.hamiltonian import QuadraticControlCost, SeparableHamiltonian
from mfgarchon.geometry import TensorProductGrid
from mfgarchon.geometry.boundary import no_flux_bc

# Create 1D grid with reflecting boundary conditions
grid = TensorProductGrid(
    bounds=[(0.0, 1.0)],
    Nx_points=[51],
    boundary_conditions=no_flux_bc(dimension=1),
)

print(f"Domain: [0, 1], {grid.num_spatial_points} points, dx = {grid.get_grid_spacing()[0]:.4f}")

# %% [markdown]
# ## Step 2: Define MFG Components
#
# The **Hamiltonian** encodes the agent's optimization problem. For LQ-MFG:
#
# $$H(x, p, m) = \underbrace{\frac{1}{2}|p|^2}_{\text{control cost}} + \underbrace{\lambda \cdot m}_{\text{congestion}}$$
#
# The optimal control (agent velocity) is $\alpha^* = -\nabla u$, derived from $\alpha^* = -D_p H = -p$.
#
# We also need:
# - **Terminal cost** $u_T(x)$: what agents pay at final time based on position
# - **Initial density** $m_0(x)$: where agents start

# %%
# Physical parameters
sigma = 0.1  # Noise intensity (SDE volatility)
coupling = 0.5  # Congestion cost strength

# Hamiltonian: H(p, m) = |p|^2/2 + coupling * m
hamiltonian = SeparableHamiltonian(
    control_cost=QuadraticControlCost(control_cost=1.0),
    coupling=lambda m: coupling * m,
    coupling_dm=lambda m: coupling,  # dF/dm for Newton linearization
)


# Terminal cost: agents want to be at x = 0.5
def terminal_cost(x):
    return (x - 0.5) ** 2


# Initial density: Gaussian peak at x = 0.5
def initial_density(x):
    return np.exp(-50 * (x - 0.5) ** 2)


# Bundle into MFGComponents
components = MFGComponents(
    hamiltonian=hamiltonian,
    u_terminal=terminal_cost,
    m_initial=initial_density,
)

# %% [markdown]
# ## Step 3: Create and Solve
#
# `MFGProblem.solve()` runs a **Picard fixed-point iteration**:
#
# 1. Initialize $U^0, M^0$
# 2. Solve HJB backward: $U^{k+1} = \text{HJB\_solve}(M^k)$
# 3. Solve FP forward: $M^{k+1} = \text{FP\_solve}(U^{k+1})$
# 4. Check convergence: $\|U^{k+1} - U^k\| + \|M^{k+1} - M^k\| < \varepsilon$
# 5. Repeat until convergence

# %%
problem = MFGProblem(
    geometry=grid,
    T=1.0,  # Time horizon
    Nt=50,  # Number of time steps
    sigma=sigma,
    components=components,
)

result = problem.solve(verbose=True)

# %% [markdown]
# ## Step 4: Inspect the Solution

# %%
print(f"Converged: {result.converged}")
print(f"Iterations: {result.iterations}")
print(f"Final error: {result.max_error:.6e}")
print(f"U shape: {result.U.shape}  (Nt+1 x Nx)")
print(f"M shape: {result.M.shape}  (Nt+1 x Nx)")

# Mass conservation check
dx = grid.get_grid_spacing()[0]
mass_initial = np.sum(result.M[0, :]) * dx
mass_final = np.sum(result.M[-1, :]) * dx
print(f"\nMass at t=0: {mass_initial:.6f}")
print(f"Mass at t=T: {mass_final:.6f}")
print(f"Mass error:  {abs(mass_final - mass_initial):.2e}")

# %% [markdown]
# ## Step 5: Visualize
#
# **Left:** The value function $u(T, x)$ shows the terminal cost landscape.
#
# **Right:** The density evolution $m(t, x)$ shows how agents redistribute over time. With congestion coupling, agents spread out from the initial concentration to reduce crowding costs.

# %%
import matplotlib.pyplot as plt

fig, axes = plt.subplots(1, 3, figsize=(15, 4))

x = grid.coordinates[0]
t = np.linspace(0, problem.T, problem.Nt + 1)

# Value function at several times
for t_idx in [0, problem.Nt // 2, problem.Nt]:
    axes[0].plot(x, result.U[t_idx, :], label=f"t = {t[t_idx]:.1f}")
axes[0].set_xlabel("x")
axes[0].set_ylabel("u(t, x)")
axes[0].set_title("Value Function")
axes[0].legend()
axes[0].grid(True, alpha=0.3)

# Density at several times
for t_idx in [0, problem.Nt // 4, problem.Nt // 2, problem.Nt]:
    axes[1].plot(x, result.M[t_idx, :], label=f"t = {t[t_idx]:.1f}")
axes[1].set_xlabel("x")
axes[1].set_ylabel("m(t, x)")
axes[1].set_title("Density Snapshots")
axes[1].legend()
axes[1].grid(True, alpha=0.3)

# Density heatmap
X, T_grid = np.meshgrid(x, t)
contour = axes[2].contourf(X, T_grid, result.M, levels=20, cmap="viridis")
axes[2].set_xlabel("x")
axes[2].set_ylabel("t")
axes[2].set_title("Density Evolution m(t,x)")
plt.colorbar(contour, ax=axes[2])

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Summary
#
# | Concept | Code |
# |:--------|:-----|
# | Domain | `TensorProductGrid(bounds=[(0,1)], Nx_points=[51], boundary_conditions=no_flux_bc(1))` |
# | Hamiltonian | `SeparableHamiltonian(control_cost=..., coupling=..., coupling_dm=...)` |
# | Conditions | `MFGComponents(hamiltonian=H, u_terminal=..., m_initial=...)` |
# | Solve | `result = MFGProblem(geometry=grid, T=1, Nt=50, components=...).solve()` |
# | Results | `result.U`, `result.M`, `result.converged`, `result.iterations` |
#
# **Next:** [Tutorial 02 — Custom Hamiltonian](./02_custom_hamiltonian.ipynb)
