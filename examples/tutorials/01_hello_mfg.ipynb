# %% [markdown]
# # Tutorial 01: Hello Mean Field Games
#
# This tutorial solves the simplest Mean Field Game — the **Linear-Quadratic (LQ) MFG** on a 1D domain.
#
# ## Mathematical Problem
#
# We solve the coupled HJB-FP system on $\Omega = [0, 1]$, $t \in [0, T]$:
#
# **Hamilton-Jacobi-Bellman (backward in time):**
# $$-\partial_t u - \frac{\sigma^2}{2} \Delta u + \frac{1}{2}|\nabla u|^2 = F(m)$$
#
# **Fokker-Planck (forward in time):**
# $$\partial_t m - \frac{\sigma^2}{2} \Delta m + \nabla \cdot (m \, \nabla u) = 0$$
#
# where:
# - $u(t,x)$ is the **value function** (cost-to-go for a representative agent)
# - $m(t,x)$ is the **population density** (distribution of agents)
# - $F(m) = \lambda \cdot m$ is a **linear congestion coupling** (crowded = costly)
# - $\sigma$ is the **noise intensity** (random perturbations in agent dynamics)
#
# **Boundary conditions:** No-flux (reflecting walls): $\nabla u \cdot n = 0$, $J \cdot n = 0$
#
# **Terminal/Initial conditions:**
# - $u(T, x) = (x - 0.5)^2$ — agents want to be at $x = 0.5$ at final time
# - $m(0, x) \propto \exp(-50(x-0.5)^2)$ — agents start concentrated near center
#
# ## API Structure
#
# MFGArchon decomposes an MFG problem into orthogonal components:
#
# | Component | What it defines | Code |
# |:----------|:---------------|:-----|
# | **Model** | Game rules: Hamiltonian $H(x,p,m)$ + diffusion $\sigma$ | `Model(hamiltonian=..., sigma=...)` |
# | **Domain** | Spatial arena: $\Omega$, grid, boundary conditions | `TensorProductGrid(...)` |
# | **Conditions** | Problem data: $u_T(x)$, $m_0(x)$, $T$ | `Conditions(u_terminal=..., m_initial=..., T=...)` |

# %% [markdown]
# ## Step 1: Define the Model (game rules)
#
# The **Model** encodes the game physics: the Hamiltonian $H(x, p, m)$ and diffusion $\sigma$.
#
# The Hamiltonian for LQ-MFG is:
# $$H(p, m) = \underbrace{\frac{1}{2}|p|^2}_{\text{control cost}} + \underbrace{\lambda \cdot m}_{\text{congestion}}$$
#
# The optimal control (agent velocity) is $\alpha^* = -D_p H = -p = -\nabla u$.

# %%
import numpy as np

from mfgarchon import Conditions, MFGProblem, Model
from mfgarchon.core.hamiltonian import QuadraticControlCost, SeparableHamiltonian
from mfgarchon.geometry import TensorProductGrid
from mfgarchon.geometry.boundary import no_flux_bc

# Physical parameters
sigma = 0.1  # Noise intensity (SDE volatility)
coupling = 0.5  # Congestion cost strength

# Hamiltonian: H(p, m) = |p|^2/2 + coupling * m
hamiltonian = SeparableHamiltonian(
    control_cost=QuadraticControlCost(control_cost=1.0),
    coupling=lambda m: coupling * m,
    coupling_dm=lambda m: coupling,  # dF/dm for Newton linearization
)

model = Model(hamiltonian=hamiltonian, sigma=sigma)
print(f"Model: H(p, m) = |p|^2/2 + {coupling}*m, sigma = {sigma}")

# %% [markdown]
# ## Step 2: Define the Domain (spatial arena)
#
# The **Domain** specifies where the game is played: spatial bounds, grid resolution, and boundary conditions.
#
# We discretize $\Omega = [0, 1]$ with 51 grid points ($\Delta x = 0.02$) and reflecting (no-flux) boundaries.

# %%
# Create 1D grid with reflecting boundary conditions
domain = TensorProductGrid(
    bounds=[(0.0, 1.0)],
    Nx_points=[51],
    boundary_conditions=no_flux_bc(dimension=1),
)

print(f"Domain: [0, 1], {domain.num_spatial_points} points, dx = {domain.get_grid_spacing()[0]:.4f}")

# %% [markdown]
# ## Step 3: Define the Conditions (problem data)
#
# **Conditions** hold the problem data that is independent of the model and domain:
# - $u_T(x)$: terminal cost (what agents pay at final time)
# - $m_0(x)$: initial density (where agents start)
# - $T$: time horizon
#
# Both $u_T$ and $m_0$ are **callables** (not arrays) — the same conditions work on any grid resolution.

# %%
conditions = Conditions(
    u_terminal=lambda x: (x - 0.5) ** 2,  # Agents want to be at x = 0.5
    m_initial=lambda x: np.exp(-50 * (x - 0.5) ** 2),  # Start near center
    T=1.0,  # Time horizon
)

print(f"Conditions: T = {conditions.T}, u_T(x) = (x-0.5)^2, m_0 = Gaussian")

# %% [markdown]
# ## Step 4: Create and Solve
#
# `MFGProblem` combines the three components. `solve()` runs **Picard fixed-point iteration**:
#
# 1. Initialize $U^0, M^0$
# 2. Solve HJB backward: $U^{k+1} \leftarrow$ `HJB_solve`$(M^k)$
# 3. Solve FP forward: $M^{k+1} \leftarrow$ `FP_solve`$(U^{k+1})$
# 4. Check convergence: $\|U^{k+1} - U^k\| + \|M^{k+1} - M^k\| < \varepsilon$
# 5. Repeat until convergence

# %%
problem = MFGProblem(model=model, domain=domain, conditions=conditions, Nt=50)
result = problem.solve(verbose=True)

# %% [markdown]
# ## Step 5: Inspect the Solution

# %%
print(f"Converged: {result.converged}")
print(f"Iterations: {result.iterations}")
print(f"Final error: {result.max_error:.6e}")
print(f"U shape: {result.U.shape}  (Nt+1 x Nx)")
print(f"M shape: {result.M.shape}  (Nt+1 x Nx)")

# Mass conservation check
dx = domain.get_grid_spacing()[0]
mass_initial = np.sum(result.M[0, :]) * dx
mass_final = np.sum(result.M[-1, :]) * dx
print(f"\nMass at t=0: {mass_initial:.6f}")
print(f"Mass at t=T: {mass_final:.6f}")
print(f"Mass error:  {abs(mass_final - mass_initial):.2e}")

# %% [markdown]
# ## Summary
#
# | Concept | Code |
# |:--------|:-----|
# | **Model** (game rules) | `Model(hamiltonian=SeparableHamiltonian(...), sigma=0.1)` |
# | **Domain** (space) | `TensorProductGrid(bounds=[(0,1)], Nx_points=[51], boundary_conditions=no_flux_bc(1))` |
# | **Conditions** (data) | `Conditions(u_terminal=lambda x: ..., m_initial=lambda x: ..., T=1.0)` |
# | **Problem** | `MFGProblem(model=model, domain=domain, conditions=conditions, Nt=50)` |
# | **Solve** | `result = problem.solve()` |
# | **Results** | `result.U`, `result.M`, `result.converged`, `result.iterations` |
# | **Vary params** | `problem.with_sigma(0.2)`, `problem.with_T(2.0)` |
#
# **Next:** [Tutorial 02 — Custom Hamiltonian](./02_custom_hamiltonian.ipynb)

# %% [markdown]
# ## Step 6: Visualize
#
# **Left:** Value function $u(t, x)$ at several time snapshots.
#
# **Center:** Density snapshots — agents spread out from the initial concentration to reduce congestion.
#
# **Right:** Density heatmap $m(t, x)$ showing the full spacetime evolution.

# %%
import matplotlib.pyplot as plt

fig, axes = plt.subplots(1, 3, figsize=(15, 4))

x = domain.coordinates[0]
t = np.linspace(0, problem.T, problem.Nt + 1)

# Value function at several times
for t_idx in [0, problem.Nt // 2, problem.Nt]:
    axes[0].plot(x, result.U[t_idx, :], label=f"t = {t[t_idx]:.1f}")
axes[0].set_xlabel("x")
axes[0].set_ylabel("u(t, x)")
axes[0].set_title("Value Function")
axes[0].legend()
axes[0].grid(True, alpha=0.3)

# Density at several times
for t_idx in [0, problem.Nt // 4, problem.Nt // 2, problem.Nt]:
    axes[1].plot(x, result.M[t_idx, :], label=f"t = {t[t_idx]:.1f}")
axes[1].set_xlabel("x")
axes[1].set_ylabel("m(t, x)")
axes[1].set_title("Density Snapshots")
axes[1].legend()
axes[1].grid(True, alpha=0.3)

# Density heatmap
X, T_grid = np.meshgrid(x, t)
contour = axes[2].contourf(X, T_grid, result.M, levels=20, cmap="viridis")
axes[2].set_xlabel("x")
axes[2].set_ylabel("t")
axes[2].set_title("Density Evolution m(t,x)")
plt.colorbar(contour, ax=axes[2])

plt.tight_layout()
plt.show()
