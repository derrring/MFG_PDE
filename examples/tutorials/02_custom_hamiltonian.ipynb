# %% [markdown]
# # Tutorial 02: Custom Hamiltonian
#
# This tutorial shows how to define a **custom Hamiltonian** for an MFG problem. We model a **crowd evacuation with congestion**, where movement becomes costlier in crowded areas.
#
# ## Mathematical Problem
#
# We solve the coupled HJB-FP system on $\Omega = [0, 1]$, $t \in [0, T]$:
#
# **Hamilton-Jacobi-Bellman (backward):**
# $$-\partial_t u - \frac{\sigma^2}{2} \Delta u + H(x, m, \nabla u) = 0$$
#
# **Fokker-Planck (forward):**
# $$\partial_t m - \frac{\sigma^2}{2} \Delta m + \nabla \cdot \left( m \, D_p H(x, m, \nabla u) \right) = 0$$
#
# ### The Congestion Hamiltonian
#
# Instead of the standard quadratic $H = \frac{1}{2}|p|^2$, we use a **density-dependent** Hamiltonian:
#
# $$H(x, m, p) = \frac{1}{2}|p|^2 + \lambda \, m \, |p|^2$$
#
# where:
# - $\frac{1}{2}|p|^2$ is the standard control cost (kinetic energy)
# - $\lambda \, m \, |p|^2$ is the **congestion penalty** -- movement costs scale with local density $m$
# - $\lambda > 0$ is the congestion strength parameter
#
# **Physical interpretation:** In crowded areas ($m$ large), the effective movement cost increases. Agents avoid dense regions not just because of the coupling cost $F(m)$, but because it is physically harder to move through a crowd.
#
# ### Derivatives (needed by the solver)
#
# The solver requires:
# - $D_p H = p + 2\lambda m p = p(1 + 2\lambda m)$ -- determines the **optimal drift** $\alpha^* = -D_p H$
# - $D_m H = \lambda |p|^2$ -- appears in the FP equation
#
# ### Conditions
# - **Terminal cost:** $u_T(x) = (x - 1)^2$ -- agents want to reach the exit at $x = 1$
# - **Initial density:** Uniform on $[0.1, 0.9]$ -- crowd distributed across the domain

# %% [markdown]
# ## Step 1: Define the Custom Hamiltonian
#
# Subclass `HamiltonianBase` and implement three methods:
# - `__call__(x, m, p, t)` -- evaluate $H(x, m, p)$
# - `dp(x, m, p, t)` -- evaluate $\partial H / \partial p$
# - `dm(x, m, p, t)` -- evaluate $\partial H / \partial m$

# %%
import numpy as np

from mfgarchon import Conditions, MFGProblem, Model
from mfgarchon.core.hamiltonian import HamiltonianBase
from mfgarchon.geometry import TensorProductGrid
from mfgarchon.geometry.boundary import no_flux_bc


class CongestionHamiltonian(HamiltonianBase):
    """
    Custom Hamiltonian for crowd evacuation with congestion.

    H(x, m, p) = (1/2)|p|^2 + lambda*m*|p|^2

    The congestion term lambda*m*|p|^2 makes movement harder in crowded areas.
    """

    def __init__(self, congestion_strength: float = 2.0):
        super().__init__()
        self.congestion_strength = congestion_strength

    def __call__(self, x, m, p, t=0.0):
        """Evaluate H(x, m, p, t)."""
        standard_cost = 0.5 * p**2
        congestion_cost = self.congestion_strength * m * p**2
        return standard_cost + congestion_cost

    def dp(self, x, m, p, t=0.0):
        """dH/dp = p + 2*lambda*m*p. Used to compute optimal control."""
        return p + 2 * self.congestion_strength * m * p

    def dm(self, x, m, p, t=0.0):
        """dH/dm = lambda*|p|^2. Appears in FP drift term."""
        return self.congestion_strength * p**2

# %% [markdown]
# ## Step 2: Set Up the Model and Conditions
#
# We define the spatial grid, then separate the problem into **Model** (game rules: Hamiltonian + diffusion) and **Conditions** (problem data: terminal cost, initial density, time horizon).

# %%
# Create grid
grid = TensorProductGrid(
    bounds=[(0.0, 1.0)],
    Nx_points=[61],
    boundary_conditions=no_flux_bc(dimension=1),
)

# Physical parameters
sigma = 0.1  # SDE volatility
congestion_strength = 2.0


# Terminal cost: distance to exit at x=1
def terminal_cost(x):
    """Agents want to be close to exit (x=1) at final time."""
    return (x - 1.0) ** 2


# Initial density: uniform on [0.1, 0.9]
def initial_density(x):
    """Uniform crowd distribution, avoiding boundaries."""
    density = np.where((x >= 0.1) & (x <= 0.9), 1.0, 0.01)
    return density


# Create custom Hamiltonian
hamiltonian = CongestionHamiltonian(congestion_strength=congestion_strength)

# Model: game rules (Hamiltonian + diffusion)
model = Model(hamiltonian=hamiltonian, sigma=sigma)

# Conditions: problem data (terminal cost, initial density, time horizon)
conditions = Conditions(u_terminal=terminal_cost, m_initial=initial_density, T=1.0)

# %% [markdown]
# ## Step 3: Solve the MFG System
#
# The solver handles the custom Hamiltonian transparently -- it calls `H(x, m, p)`, `dp(x, m, p)`, and `dm(x, m, p)` at each grid point during the Picard iteration.

# %%
problem = MFGProblem(
    model=model,
    domain=grid,
    conditions=conditions,
    Nt=50,
)

print(f"Congestion strength: lambda = {congestion_strength}")
result = problem.solve(verbose=True)

print(f"\nConverged: {result.converged} (iterations: {result.iterations})")

# %% [markdown]
# ## Step 4: Analyze the Congestion Effect
#
# To quantify the impact of congestion, we solve the same problem with $\lambda = 0$ (no congestion) and compare how much mass reaches the exit zone $x > 0.9$ by the terminal time.

# %%
# Solve baseline (no congestion) using with_model
baseline_hamiltonian = CongestionHamiltonian(congestion_strength=0.0)
baseline = problem.with_model(Model(hamiltonian=baseline_hamiltonian, sigma=sigma))
result_baseline = baseline.solve(verbose=False)

# Measure evacuation efficiency
x = grid.coordinates[0]
dx = grid.get_grid_spacing()[0]
exit_mask = x > 0.9
exit_mass_congested = np.sum(result.M[-1, exit_mask]) * dx
exit_mass_baseline = np.sum(result_baseline.M[-1, exit_mask]) * dx

print(f"Mass at exit (with congestion):    {exit_mass_congested:.3f}")
print(f"Mass at exit (without congestion): {exit_mass_baseline:.3f}")
if exit_mass_baseline > 0:
    slowdown = (1 - exit_mass_congested / exit_mass_baseline) * 100
    print(f"Evacuation slowdown: {slowdown:.1f}%")

# %% [markdown]
# ## Step 5: Visualize
#
# We compare density evolution and terminal states between the congested and non-congested cases.
#
# **What to observe:**
# - **Top-left:** With congestion, density spreads more slowly toward the exit
# - **Top-right:** Without congestion, agents concentrate near the exit more freely
# - **Bottom-left:** The final density at $t=T$ is more spread out with congestion
# - **Bottom-right:** The value function $u(T,x)$ is higher with congestion (movement is costlier)

# %%
import matplotlib.pyplot as plt

fig, axes = plt.subplots(2, 2, figsize=(12, 10))

t = np.linspace(0, problem.T, problem.Nt + 1)
X, T_grid = np.meshgrid(x, t)

# Density evolution with congestion
ax = axes[0, 0]
c = ax.contourf(X, T_grid, result.M, levels=20, cmap="viridis")
ax.set_xlabel("x")
ax.set_ylabel("t")
ax.set_title(f"Density with congestion (lambda={congestion_strength})")
plt.colorbar(c, ax=ax)

# Density evolution without congestion
ax = axes[0, 1]
c = ax.contourf(X, T_grid, result_baseline.M, levels=20, cmap="viridis")
ax.set_xlabel("x")
ax.set_ylabel("t")
ax.set_title("Density without congestion (lambda=0)")
plt.colorbar(c, ax=ax)

# Final density comparison
ax = axes[1, 0]
ax.plot(x, result.M[-1, :], "b-", linewidth=2, label=f"lambda={congestion_strength}")
ax.plot(x, result_baseline.M[-1, :], "r--", linewidth=2, label="lambda=0")
ax.axvline(x=0.9, color="g", linestyle=":", label="Exit zone")
ax.set_xlabel("x")
ax.set_ylabel("m(T, x)")
ax.set_title("Final Density Comparison")
ax.legend()
ax.grid(True, alpha=0.3)

# Value function comparison
ax = axes[1, 1]
ax.plot(x, result.U[-1, :], "b-", linewidth=2, label=f"lambda={congestion_strength}")
ax.plot(x, result_baseline.U[-1, :], "r--", linewidth=2, label="lambda=0")
ax.set_xlabel("x")
ax.set_ylabel("u(T, x)")
ax.set_title("Terminal Value Function Comparison")
ax.legend()
ax.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Summary
#
# | Concept | Implementation |
# |:--------|:--------------|
# | Custom Hamiltonian | Subclass `HamiltonianBase`, implement `__call__`, `dp`, `dm` |
# | Model | `Model(hamiltonian=..., sigma=...)` -- game rules |
# | Conditions | `Conditions(u_terminal=..., m_initial=..., T=...)` -- problem data |
# | Variant comparison | `problem.with_model(...)` -- swap game rules, keep everything else |
# | Congestion effect | Movement costs scale with density via congestion penalty term |
#
# The congestion Hamiltonian:
#
# $$H(x, m, p) = \frac{1}{2}|p|^2 + \lambda \, m \, |p|^2$$
#
# The optimal drift (from the Hamiltonian derivative):
#
# $$\alpha^* = -D_p H = -p(1 + 2\lambda m)$$
#
# **Key insight:** The congestion term creates a feedback loop: high density makes movement expensive, causing agents to spread out.
#
# **Next:** [Tutorial 03 -- 2D Geometry](./03_2d_geometry.ipynb)
