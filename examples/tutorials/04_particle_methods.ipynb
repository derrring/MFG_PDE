# %% [markdown]
# # Tutorial 04: Advanced Solver Configuration
#
# This tutorial demonstrates how to configure MFG solvers with **custom parameters** using the `MFGSolverConfig` and `SolverFactory` APIs.
#
# ## Motivation
#
# The Picard fixed-point iteration that solves the HJB-FP system has several tunable parameters:
#
# - **Tolerance** $\varepsilon$: convergence threshold $\|U^{k+1} - U^k\| + \|M^{k+1} - M^k\| < \varepsilon$
# - **Max iterations**: upper bound on Picard iterations
#
# The tolerance controls the **accuracy vs. speed trade-off**:
#
# | Tolerance | Use Case | Typical Iterations |
# |:----------|:---------|:------------------|
# | $10^{-3}$ | Quick prototyping | Few |
# | $10^{-5}$ | Standard research | Moderate |
# | $10^{-6}$ to $10^{-8}$ | Publication quality | Many |
#
# ### Configuration Architecture
#
# MFGArchon uses a dual configuration system:
# - `MFGSolverConfig` (Pydantic) -- runtime configuration with validation
# - `PicardConfig` -- controls the fixed-point iteration parameters
# - `SolverFactory` -- creates solvers from problems and configs

# %% [markdown]
# ## Step 1: Solve with Default Settings
#
# First, we solve a standard LQ-MFG problem with default configuration to establish a baseline.

# %%
import numpy as np

from mfgarchon import Conditions, MFGProblem, Model
from mfgarchon.config import MFGSolverConfig, PicardConfig
from mfgarchon.core.hamiltonian import QuadraticControlCost, SeparableHamiltonian
from mfgarchon.factory import SolverFactory
from mfgarchon.geometry import TensorProductGrid
from mfgarchon.geometry.boundary import no_flux_bc

# Create grid
grid = TensorProductGrid(bounds=[(0.0, 1.0)], Nx_points=[51], boundary_conditions=no_flux_bc(dimension=1))

hamiltonian = SeparableHamiltonian(
    control_cost=QuadraticControlCost(control_cost=1.0),
    coupling=lambda m: 0.3 * m,
    coupling_dm=lambda m: 0.3,
)

model = Model(hamiltonian=hamiltonian, sigma=0.15)
conditions = Conditions(
    u_terminal=lambda x: (x - 0.5) ** 2,
    m_initial=lambda x: np.exp(-50 * (x - 0.5) ** 2),
    T=1.0,
)

problem = MFGProblem(
    model=model,
    domain=grid,
    conditions=conditions,
    Nt=50,
)

print("Solving with DEFAULT settings...")
result_default = problem.solve(verbose=True)

print(f"\nDefault: Converged in {result_default.iterations} iterations")
print(f"  Final error: {result_default.max_error:.6e}")

# %% [markdown]
# ## Step 2: Custom Configuration -- Tighter Tolerance
#
# Use `MFGSolverConfig` with `PicardConfig` to request higher accuracy. The `SolverFactory` creates a solver that respects these settings.

# %%
# Configuration with tighter tolerance
config_tight = MFGSolverConfig(
    picard=PicardConfig(
        max_iterations=50,
        tolerance=1e-6,
    )
)

print(f"Config: max_iterations={config_tight.picard.max_iterations}, tol={config_tight.picard.tolerance}")

# Create solver with custom config
solver_tight = SolverFactory.create_solver(problem, config=config_tight)
result_tight = solver_tight.solve(verbose=True)

print(f"\nTight tolerance: Converged in {result_tight.iterations} iterations")
print(f"  Final error: {result_tight.max_error:.6e}")

# %% [markdown]
# ## Step 3: Looser Tolerance for Speed
#
# For rapid prototyping, a looser tolerance converges faster at the cost of accuracy.

# %%
config_fast = MFGSolverConfig(
    picard=PicardConfig(
        max_iterations=20,
        tolerance=1e-3,
    )
)

solver_fast = SolverFactory.create_solver(problem, config=config_fast)
result_fast = solver_fast.solve(verbose=True)

print(f"\nFast (loose tol): Converged in {result_fast.iterations} iterations")
print(f"  Final error: {result_fast.max_error:.6e}")

# %% [markdown]
# ## Step 4: Compare Solutions
#
# We quantify how much the solutions differ across tolerance settings. The relative $L^2$ difference measures:
#
# $$\text{rel. diff} = \frac{\|M_{\text{variant}} - M_{\text{default}}\|_2}{\|M_{\text{default}}\|_2}$$

# %%
# Relative L2 differences
diff_tight_default = np.linalg.norm(result_tight.M - result_default.M) / np.linalg.norm(result_default.M)
diff_fast_default = np.linalg.norm(result_fast.M - result_default.M) / np.linalg.norm(result_default.M)

print("Relative L2 differences from default:")
print(f"  Tight tolerance vs Default: {diff_tight_default:.6e}")
print(f"  Fast (loose) vs Default:    {diff_fast_default:.6e}")

# Mass conservation check
dx = problem.geometry.get_grid_spacing()[0]
mass_default = np.sum(result_default.M[-1, :]) * dx
mass_tight = np.sum(result_tight.M[-1, :]) * dx
mass_fast = np.sum(result_fast.M[-1, :]) * dx

print("\nFinal mass (should be consistent):")
print(f"  Default:         {mass_default:.6f}")
print(f"  Tight tolerance: {mass_tight:.6f}")
print(f"  Fast:            {mass_fast:.6f}")

# Summary table
print("\n" + "=" * 70)
print(f"{'Configuration':<20} {'Tolerance':<12} {'Iterations':<12} {'Final Error':<12}")
print("-" * 70)
for name, result, tol in [
    ("Default", result_default, 1e-5),
    ("Tight (1e-6)", result_tight, 1e-6),
    ("Fast (1e-3)", result_fast, 1e-3),
]:
    print(f"{name:<20} {tol:<12.0e} {result.iterations:<12} {result.max_error:.4e}")

# %% [markdown]
# ## Step 5: Visualize the Comparison
#
# **What to observe:**
# - **Left:** Final density profiles should nearly overlap -- all configurations solve the same problem
# - **Center:** Terminal value functions should also agree closely
# - **Right:** Convergence histories show how quickly each configuration reaches its tolerance

# %%
import matplotlib.pyplot as plt

fig, axes = plt.subplots(1, 3, figsize=(15, 4))

x = grid.coordinates[0]

# Final density comparison
axes[0].plot(x, result_default.M[-1, :], "b-", linewidth=2, label="Default")
axes[0].plot(x, result_tight.M[-1, :], "g--", linewidth=2, label="Tight", alpha=0.8)
axes[0].plot(x, result_fast.M[-1, :], "r:", linewidth=2, label="Fast", alpha=0.8)
axes[0].set_xlabel("x")
axes[0].set_ylabel("m(T, x)")
axes[0].set_title("Final Density Comparison")
axes[0].legend()
axes[0].grid(True, alpha=0.3)

# Value function comparison
axes[1].plot(x, result_default.U[-1, :], "b-", linewidth=2, label="Default")
axes[1].plot(x, result_tight.U[-1, :], "g--", linewidth=2, label="Tight", alpha=0.8)
axes[1].plot(x, result_fast.U[-1, :], "r:", linewidth=2, label="Fast", alpha=0.8)
axes[1].set_xlabel("x")
axes[1].set_ylabel("u(T, x)")
axes[1].set_title("Terminal Value Function")
axes[1].legend()
axes[1].grid(True, alpha=0.3)

# Convergence comparison
if hasattr(result_default, "error_history_M") and result_default.error_history_M:
    axes[2].semilogy(result_default.error_history_M, "b-", label="Default", linewidth=2)
if hasattr(result_tight, "error_history_M") and result_tight.error_history_M:
    axes[2].semilogy(result_tight.error_history_M, "g--", label="Tight", linewidth=2)
if hasattr(result_fast, "error_history_M") and result_fast.error_history_M:
    axes[2].semilogy(result_fast.error_history_M, "r:", label="Fast", linewidth=2)
axes[2].set_xlabel("Iteration")
axes[2].set_ylabel("Error (log scale)")
axes[2].set_title("Convergence History")
axes[2].legend()
axes[2].grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Summary
#
# | API Element | Purpose |
# |:------------|:--------|
# | `MFGSolverConfig` | Top-level configuration container |
# | `PicardConfig` | Controls fixed-point iteration (tolerance, max iterations) |
# | `SolverFactory.create_solver()` | Creates solver from problem + config |
# | `problem.solve()` | Uses default config (quick start) |
#
# **Best practices:**
# - Start with `problem.solve()` (default settings) for initial exploration
# - Use `MFGSolverConfig` + `SolverFactory` when you need fine-grained control
# - Use $\varepsilon = 10^{-3}$ for prototyping, $10^{-6}$ for final results
# - Monitor convergence history to diagnose issues
#
# **Next:** [Tutorial 05 -- Problem Variations](./05_config_system.ipynb)
